# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mobile=pd.read_csv('C:/Users/admin/Downloads/mobile_train.csv')
mobile.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
max_battery=mobile['battery_power'].max()
max_battery
# Out:
# 1998

# %%
min_battery=mobile['battery_power'].min()
min_battery
# Out:
# 501

# %%
print(len(mobile['dual_sim']))
# Out:
# 2000

# %%
mobile['battery_power'].mean()
# Out:
# 1238.5185

# %%
mobile[['mobile_wt','battery_power']].groupby('battery_power').min()
# Out:
#                mobile_wt
# battery_power
# 501                  131
# 502                   82
# 503                  111
# 504                  163
# 506                  159
# ...                  ...
# 1994                  88
# 1995                 129
# 1996                 122
# 1997                 185
# 1998                 196
#
# [1094 rows x 1 columns]

# %%
mobile.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
mobile_corr=mobile.corr()

# %%
sns.heatmap(mobile_corr,annot=False,vmin=-1,vmax=1,cmap='Purples')
plt.show()

# %%
sns.countplot(mobile['dual_sim'])
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='dual_sim', ylabel='count'>

# %%
corr=mobile.corr()
fig=plt.figure(figsize=(15,12))
r=sns.heatmap(corr,cmap='Purples')
r.set_title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %% [markdown]
# As we can see our target price range has highly positive correlation between ram

# %%
mobile['price_range'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
sns.boxplot(mobile['price_range'],mobile['talk_time'])
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price_range', ylabel='talk_time'>

# %%
labels=['3G-supported','Not supported']
values=mobile['three_g'].value_counts().values

# %%
fig1,ax1=plt.subplots()
colors=['gold','lightskyblue']
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90,colors=colors)
plt.show()

# %%
labels=['4G-supported','Not supported']
values=mobile['four_g'].value_counts().values

# %%
fig1,ax1=plt.subplots()
colors=['pink','violet']
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90,colors=colors)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.svm import SVC

# %%
scaler=StandardScaler()
x=mobile.drop('price_range',axis=1)
y=mobile['price_range']# 0,1 ,2,3 classification clusters

scaler.fit(x)
x_transformed=scaler.transform(x)
x_train,x_test,y_train,y_test=train_test_split(x_transformed,y,test_size=0.3)

# %%
#SVM
model=SVC()
model.fit(x_train,y_train)
y_train_pred=model.predict(x_train)
y_test_pred=model.predict(x_test)


print("Train Set Accuracy:"+str(accuracy_score(y_train_pred,y_train)*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test_pred,y_test)*100))
print("\nConfusion Matrix:\n%s"%confusion_matrix(y_test,y_test))
print("\nClassificationReport:\n%s"%classification_report(y_test_pred,y_test))
# Out:
# Train Set Accuracy:98.5
# Test Set Accuracy:87.66666666666667
#
# Confusion Matrix:
# [[151   0   0   0]
#  [  0 155   0   0]
#  [  0   0 158   0]
#  [  0   0   0 136]]
#
# ClassificationReport:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       145
#            1       0.89      0.80      0.84       173
#            2       0.80      0.86      0.83       148
#            3       0.91      0.93      0.92       134
#
#     accuracy                           0.88       600
#    macro avg       0.88      0.88      0.88       600
# weighted avg       0.88      0.88      0.88       600
